# %% [markdown]
# # <center><u>Deleting Rows/Columns from DataFrame and Renaming columns</u> </center>

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('titanic.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.shape
# Out:
# (891, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# ?data.drop // help
# Out:
# Object `data.drop # help` not found.

# %% [markdown]
# **labels** – Single label or list-like. It’s used with axis param.
#
# **axis** – Default set’s to 0. 1 to drop columns and 0 to drop rows.
#
# **index** – Use to specify rows. Accepts single label or list-like.
#
# **columns** – Use to specify columns. Accepts single label or list-like.
#
# **level** – int or level name, optional, use for Multiindex.
#
# **inplace** – Default False, returns a copy of DataFrame. When used True, it drop’s column inplace (current DataFrame) and returns None.
#
# **errors** – {‘ignore’, ‘raise’}, default ‘raise’

# %% [markdown]
# ### Dropping Row

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.drop(0,axis=0,inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q

# %%
data.drop([1,2,3],axis=0,inplace=True)

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 4      0  373450   8.0500   NaN        S
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S

# %%
data.drop([4,5],axis=0,inplace=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 4      0  373450   8.0500   NaN        S
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S

# %%
data=data.drop([4,5],axis=0,inplace=False)

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch   Ticket     Fare Cabin Embarked
# 6       0    17463  51.8625   E46        S
# 7       1   349909  21.0750   NaN        S
# 8       2   347742  11.1333   NaN        S
# 9       0   237736  30.0708   NaN        C
# 10      1  PP 9549  16.7000    G6        S

# %%
data=data.drop([4,5],axis=0,inplace=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 data=data.drop([4,5],axis=0,inplace=False)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...

# %%
data=data.drop([4,5],axis=0,inplace=False,errors='ignore')

# %% [markdown]
# By default drop() method removes rows (axis=0) from DataFrame

# %%
data = data.drop([6,7])

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
#
#     Parch     Ticket     Fare Cabin Embarked
# 8       2     347742  11.1333   NaN        S
# 9       0     237736  30.0708   NaN        C
# 10      1    PP 9549  16.7000    G6        S
# 11      0     113783  26.5500  C103        S
# 12      0  A/5. 2151   8.0500   NaN        S

# %%
data = data.drop(index=[8,9])

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 11           12         1       1              Bonnell, Miss. Elizabeth
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 10  female   4.0      1      1    PP 9549  16.7000    G6        S
# 11  female  58.0      0      0     113783  26.5500  C103        S
# 12    male  20.0      0      0  A/5. 2151   8.0500   NaN        S
# 13    male  39.0      1      5     347082  31.2750   NaN        S
# 14  female  14.0      0      0     350406   7.8542   NaN        S

# %%
data = data.drop(labels=[10,11])

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 12           13         0       3        Saundercock, Mr. William Henry
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 15           16         1       2      Hewlett, Mrs. (Mary D Kingcome)
# 16           17         0       3                  Rice, Master. Eugene
#
#        Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 12    male  20.0      0      0  A/5. 2151   8.0500   NaN        S
# 13    male  39.0      1      5     347082  31.2750   NaN        S
# 14  female  14.0      0      0     350406   7.8542   NaN        S
# 15  female  55.0      0      0     248706  16.0000   NaN        S
# 16    male   2.0      4      1     382652  29.1250   NaN        Q

# %%
data.index[0]
# Out:
# 12

# %%
data=data.drop(data.index[0])

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 15           16         1       2      Hewlett, Mrs. (Mary D Kingcome)
# 16           17         0       3                  Rice, Master. Eugene
# 17           18         1       2          Williams, Mr. Charles Eugene
#
#        Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 13    male  39.0      1      5  347082  31.2750   NaN        S
# 14  female  14.0      0      0  350406   7.8542   NaN        S
# 15  female  55.0      0      0  248706  16.0000   NaN        S
# 16    male   2.0      4      1  382652  29.1250   NaN        Q
# 17    male   NaN      0      0  244373  13.0000   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data=data.drop(data.index[-1])

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 885  female  39.0      0      5      382652  29.125   NaN        Q
# 886    male  27.0      0      0      211536  13.000   NaN        S
# 887  female  19.0      0      0      112053  30.000   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.450   NaN        S
# 889    male  26.0      0      0      111369  30.000  C148        C

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 13           14         0       3           Andersson, Mr. Anders Johan
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 15           16         1       2      Hewlett, Mrs. (Mary D Kingcome)
# 16           17         0       3                  Rice, Master. Eugene
# 17           18         1       2          Williams, Mr. Charles Eugene
#
#        Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 13    male  39.0      1      5  347082  31.2750   NaN        S
# 14  female  14.0      0      0  350406   7.8542   NaN        S
# 15  female  55.0      0      0  248706  16.0000   NaN        S
# 16    male   2.0      4      1  382652  29.1250   NaN        Q
# 17    male   NaN      0      0  244373  13.0000   NaN        S

# %%
data.index[[1,3]]
# Out:
# Int64Index([14, 16], dtype='int64')

# %%
data=data.drop(data.index[[1,3]])

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 13           14         0       3
# 15           16         1       2
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 15                   Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 17                       Williams, Mr. Charles Eugene    male   NaN      0
# 18  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# 19                            Masselmani, Mrs. Fatima  female   NaN      0
#
#     Parch  Ticket    Fare Cabin Embarked
# 13      5  347082  31.275   NaN        S
# 15      0  248706  16.000   NaN        S
# 17      0  244373  13.000   NaN        S
# 18      0  345763  18.000   NaN        S
# 19      0    2649   7.225   NaN        C

# %%
data.index[0:5]
# Out:
# Int64Index([13, 15, 17, 18, 19], dtype='int64')

# %%
data=data.drop(data.index[0:5])

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  \
# 20           21         0       2           Fynney, Mr. Joseph J    male
# 21           22         1       2          Beesley, Mr. Lawrence    male
# 22           23         1       3    McGowan, Miss. Anna "Annie"  female
# 23           24         1       1   Sloper, Mr. William Thompson    male
# 24           25         0       3  Palsson, Miss. Torborg Danira  female
#
#      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 20  35.0      0      0  239865  26.0000   NaN        S
# 21  34.0      0      0  248698  13.0000   D56        S
# 22  15.0      0      0  330923   8.0292   NaN        Q
# 23  28.0      0      0  113788  35.5000    A6        S
# 24   8.0      3      1  349909  21.0750   NaN        S

# %%
data.loc[data["Name"] == 'Beesley, Mr. Lawrence' ]
# Out:
#     PassengerId  Survived  Pclass                   Name   Sex   Age  SibSp  \
# 21           22         1       2  Beesley, Mr. Lawrence  male  34.0      0
#
#     Parch  Ticket  Fare Cabin Embarked
# 21      0  248698  13.0   D56        S

# %%
data = data.loc[data["Name"] != 'Beesley, Mr. Lawrence' ]

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
#
#     Parch  Ticket     Fare Cabin Embarked
# 20      0  239865  26.0000   NaN        S
# 22      0  330923   8.0292   NaN        Q
# 23      0  113788  35.5000    A6        S
# 24      1  349909  21.0750   NaN        S
# 25      5  347077  31.3875   NaN        S

# %% [markdown]
# ### Dropping Column

# %%
data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
#
#     Parch  Ticket     Fare Cabin Embarked
# 20      0  239865  26.0000   NaN        S
# 22      0  330923   8.0292   NaN        Q
# 23      0  113788  35.5000    A6        S
# 24      1  349909  21.0750   NaN        S
# 25      5  347077  31.3875   NaN        S

# %%
df=data.copy()

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
#
#     Parch  Ticket     Fare Cabin Embarked
# 20      0  239865  26.0000   NaN        S
# 22      0  330923   8.0292   NaN        Q
# 23      0  113788  35.5000    A6        S
# 24      1  349909  21.0750   NaN        S
# 25      5  347077  31.3875   NaN        S

# %%
df.drop('PassengerId',axis=1,inplace=True)

# %%
df.head()
# Out:
#     Survived  Pclass                                               Name  \
# 20         0       2                               Fynney, Mr. Joseph J
# 22         1       3                        McGowan, Miss. Anna "Annie"
# 23         1       1                       Sloper, Mr. William Thompson
# 24         0       3                      Palsson, Miss. Torborg Danira
# 25         1       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
#
#        Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 20    male  35.0      0      0  239865  26.0000   NaN        S
# 22  female  15.0      0      0  330923   8.0292   NaN        Q
# 23    male  28.0      0      0  113788  35.5000    A6        S
# 24  female   8.0      3      1  349909  21.0750   NaN        S
# 25  female  38.0      1      5  347077  31.3875   NaN        S

# %%
df.drop(['Survived','Pclass'],axis=1,inplace=True)

# %%
df.head()
# Out:
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
#
#     Parch  Ticket     Fare Cabin Embarked
# 20      0  239865  26.0000   NaN        S
# 22      0  330923   8.0292   NaN        Q
# 23      0  113788  35.5000    A6        S
# 24      1  349909  21.0750   NaN        S
# 25      5  347077  31.3875   NaN        S

# %%
df=df.drop(['Survived','Pclass'],axis=1,inplace=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-94e2ecdf4b05> in <module>
# ----> 1 df=df.drop(['Survived','Pclass'],axis=1,inplace=False)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df=df.drop(['Survived','Pclass'],axis=1,inplace=False,errors='ignore')

# %%
df.head()
# Out:
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
#
#     Parch  Ticket     Fare Cabin Embarked
# 20      0  239865  26.0000   NaN        S
# 22      0  330923   8.0292   NaN        Q
# 23      0  113788  35.5000    A6        S
# 24      1  349909  21.0750   NaN        S
# 25      5  347077  31.3875   NaN        S

# %%
df=df.drop(columns='Name')

# %%
df.head()
# Out:
#        Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 20    male  35.0      0      0  239865  26.0000   NaN        S
# 22  female  15.0      0      0  330923   8.0292   NaN        Q
# 23    male  28.0      0      0  113788  35.5000    A6        S
# 24  female   8.0      3      1  349909  21.0750   NaN        S
# 25  female  38.0      1      5  347077  31.3875   NaN        S

# %%
df.drop(columns=['Sex','Age'],inplace=True)

# %%
df.head()
# Out:
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 20      0      0  239865  26.0000   NaN        S
# 22      0      0  330923   8.0292   NaN        Q
# 23      0      0  113788  35.5000    A6        S
# 24      3      1  349909  21.0750   NaN        S
# 25      1      5  347077  31.3875   NaN        S

# %%
df.columns[1]
# Out:
# 'Parch'

# %%
df=df.drop(df.columns[1], axis = 1)

# %%
df.head()
# Out:
#     SibSp  Ticket     Fare Cabin Embarked
# 20      0  239865  26.0000   NaN        S
# 22      0  330923   8.0292   NaN        Q
# 23      0  113788  35.5000    A6        S
# 24      3  349909  21.0750   NaN        S
# 25      1  347077  31.3875   NaN        S

# %%
df.columns[[1,2]]
# Out:
# Index(['Ticket', 'Fare'], dtype='object')

# %%
df.drop(df.columns[[1,2]], axis = 1, inplace=True)

# %%
df.head()
# Out:
#     SibSp Cabin Embarked
# 20      0   NaN        S
# 22      0   NaN        Q
# 23      0    A6        S
# 24      3   NaN        S
# 25      1   NaN        S

# %%
df.iloc[:, 1:3]
# Out:
#     Cabin Embarked
# 20    NaN        S
# 22    NaN        Q
# 23     A6        S
# 24    NaN        S
# 25    NaN        S
# ..    ...      ...
# 885   NaN        Q
# 886   NaN        S
# 887   B42        S
# 888   NaN        S
# 889  C148        C
#
# [869 rows x 2 columns]

# %%
df.drop(df.iloc[:, 1:3], axis=1, inplace=True)

# %%
df.head()
# Out:
#     SibSp
# 20      0
# 22      0
# 23      0
# 24      3
# 25      1

# %%
df=data.copy()

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 20           21         0       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 20                               Fynney, Mr. Joseph J    male  35.0      0
# 22                        McGowan, Miss. Anna "Annie"  female  15.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
# 24                      Palsson, Miss. Torborg Danira  female   8.0      3
# 25  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...  female  38.0      1
#
#     Parch  Ticket     Fare Cabin Embarked
# 20      0  239865  26.0000   NaN        S
# 22      0  330923   8.0292   NaN        Q
# 23      0  113788  35.5000    A6        S
# 24      1  349909  21.0750   NaN        S
# 25      5  347077  31.3875   NaN        S

# %%
df.drop(df.loc[:, 'Name':'Ticket'].columns, axis = 1, inplace=True)

# %%
df.head()
# Out:
#     PassengerId  Survived  Pclass     Fare Cabin Embarked
# 20           21         0       2  26.0000   NaN        S
# 22           23         1       3   8.0292   NaN        Q
# 23           24         1       1  35.5000    A6        S
# 24           25         0       3  21.0750   NaN        S
# 25           26         1       3  31.3875   NaN        S

# %%
lisCols = ["PassengerId","PassengerId"]
df=df.drop(lisCols, axis = 1)

# %%
df.head()
# Out:
#     Survived  Pclass     Fare Cabin Embarked
# 20         0       2  26.0000   NaN        S
# 22         1       3   8.0292   NaN        Q
# 23         1       1  35.5000    A6        S
# 24         0       3  21.0750   NaN        S
# 25         1       3  31.3875   NaN        S

# %% [markdown]
# ### Renaming Columns

# %%
df.rename(columns = {'Fare':'Total_fare'}, inplace = True)

# %%
df.head()
# Out:
#     Survived  Pclass  Total_fare Cabin Embarked
# 20         0       2     26.0000   NaN        S
# 22         1       3      8.0292   NaN        Q
# 23         1       1     35.5000    A6        S
# 24         0       3     21.0750   NaN        S
# 25         1       3     31.3875   NaN        S

# %%
df.rename(columns = {'Pclass':'Pass_Class','Cabin':'Pass_Cabin'}, inplace = True)

# %%
df.head()
# Out:
#     Survived  Pass_Class  Total_fare Pass_Cabin Embarked
# 20         0           2     26.0000        NaN        S
# 22         1           3      8.0292        NaN        Q
# 23         1           1     35.5000         A6        S
# 24         0           3     21.0750        NaN        S
# 25         1           3     31.3875        NaN        S
